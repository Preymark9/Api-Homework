# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import openweathermapy.core as owm

# Import API key
api_key = "e89b372d91d9fca085a28ad0fa2c2437"#key isn't working but I'm confident the code does, may need a new key
#I changed it to my personal key. Hope it works
#I doesn't work, but I'm 90% sure my forloop code is right. I'm disappointed cuz I can't verify that for certain.

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = "e89b372d91d9fca085a28ad0fa2c2437" #this key isn't working, needs to be changed

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
settings = {"units": "imperial", "appid": api_key}
query_url = url + "appid=" + api_key + "&q=" + cities[0]
#may need to make a forloop to go through the cities list and display important data. Once displayed, add to a table, then chart the table
#need to do a json response so I can see what to loop for
#there will be many data points, a scatter plot is ideal
#may be best to graph the scatter plot by temperature, perhaps by making the y axis temperature and the x axis...hmm...lat/long
response = requests.get(query_url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))

#ran the api for paris to see what parameters to loop for in the next line. Still trying to figure out how to get this line to work the way I want
# Out:
# {
#     "cod": 401,
#     "message": "Invalid API key. Please see http://openweathermap.org/faq#error401 for more info."
# }

# %%
# set up lists to hold reponse info
lat = []
temp_min = []
temp_max = []
humidity = []
clouds = []
wind = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp_min.append(response['main']['temp_min'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
    
    except (KeyError, IndexError):
            print("Missing field/result... skipping.")
   

print(f"The latitude information received is: {lat}")
print(f"The low temperature information received is: {temp_min}")
print(f"The high temperature information received is: {temp_max}")
print(f"The humidity information received is: {humidity}")
print(f"The cloud information received is: {clouds}")
print(f"The wind speed information received is: {wind}")
#What this loop is supposed to do is make a table of the given fields. In order to make sure I listed the fields correctly, I did a json search for one city, then structured the fields to mirror the response
#I can see the loop is being performed, but even after changing my API key it doesn't like my key. Not sure why. Perhaps keys expire after a set period of time?
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# ...

# %%
#not sure why the code isn't working, I may need a new API key. Functionally the loop is being performed
#primary theory is that the API key isn't working and therefore the index loop isn't working
XA = cities("lat")
YA = cities("temp_max")
plt.scatter(XA, YA, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c7809a8678bf> in <module>()
#       1 #not sure why the code isn't working, I may need a new API key. Functionally the loop is being performed
#       2 #primary theory is that the API key isn't working and therefore the index loop isn't working
# ----> 3 XA = cities("lat")
#       4 YA = cities("temp_max")
#       5 plt.scatter(XA, YA, marker="o", facecolors="red", edgecolors="black",
#
# TypeError: 'list' object is not callable
